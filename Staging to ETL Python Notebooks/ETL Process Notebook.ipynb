# %%
pip install azure-storage-blob
# Out:
# Requirement already satisfied: azure-storage-blob in /usr/local/lib/python3.10/dist-packages (12.20.0)
# Requirement already satisfied: azure-core>=1.28.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (1.30.1)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (42.0.7)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.11.0)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (0.6.1)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (2024.2.2)

# %%
pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in /usr/local/lib/python3.10/dist-packages (3.10.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (1.16.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (42.0.7)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (24.1.0)
# Requirement already satisfied: pyjwt<3.0.0 in /usr/lib/python3/dist-packages (from snowflake-connector-python) (2.3.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (2023.4)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (24.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (2024.2.2)
# Requirement already satisfied: typing-extensions<5,>=4.3 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (4.11.0)
# Requirement already satisfied: filelock<4,>=3.5 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (3.14.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (4.2.1)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python) (0.12.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->snowflake-connector-python) (2.0.7)

# %%
#Import libraries
import pandas as pd
import numpy as np
import json
import requests
from io import StringIO
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from math import ceil
import datetime
import calendar
from sqlalchemy import create_engine
import uuid

# %%
# Azure Functions
def azure_upload_blob(connect_str, container_name, blob_name, data):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    blob_client.upload_blob(data, overwrite=True)
    print(f"Uploaded to Azure Blob: {blob_name}")

def azure_download_blob(connect_str, container_name, blob_name):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    download_stream = blob_client.download_blob()
    return download_stream.readall()

# %%
def week_of_month(dt):
    first_day = dt.replace(day=1)
    dom = dt.day
    adjusted_dom = dom + first_day.weekday()
    return int(ceil(adjusted_dom/7.0))

def get_week_of_year(date_str):
    """
    Calculate the ISO week number of the year for a given date.

    Parameters:
    date_str (str): A date string in the format 'YYYY-MM-DD'.

    Returns:
    int: ISO week number of the year.
    """
    # Parse the input string to a datetime object
    date = datetime.strptime(date_str, '%Y-%m-%d')

    # Get the ISO calendar week number
    week_of_year = date.isocalendar()[1]

    return week_of_year

# %%
# Specify the path to your JSON configuration file
config_file_path = 'config.json'

# Load the JSON configuration file
with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)

# Print the configuration
#Connection_STRING = config["connectionString"]

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = 'realestatesales'

# Initialize the BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

# Get the container client
container_client = blob_service_client.get_container_client(CONTAINER_AZURE)


real_est = pd.DataFrame()

# List all blobs in the specified container
blob_list = container_client.list_blobs()
for blob in blob_list:
    print(blob.name)
    blob_client = container_client.get_blob_client(blob=blob.name)
    blob_data = blob_client.download_blob()
    blob_content = blob_data.readall().decode('utf-8')
    df = pd.read_csv(StringIO(blob_content))
    # Display the head of the DataFrame
    print(df.shape)
    # sind I have only one csv, I am doing to do the following instructions
    real_est = df.copy()
# Out:
# realestatesalescis9440.csv
# <ipython-input-85-0290b84126e2>:30: DtypeWarning: Columns (16,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(StringIO(blob_content))
# (1054159, 26)

# %%
real_est.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054159 entries, 0 to 1054158
# Data columns (total 26 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   sid               1054159 non-null  object
#  1   id                1054159 non-null  object
#  2   position          1054159 non-null  int64
#  3   created_at        1054159 non-null  int64
#  4   created_meta      0 non-null        float64
#  5   updated_at        1054159 non-null  int64
#  6   updated_meta      0 non-null        float64
#  7   meta              1054159 non-null  object
#  8   Serial Number     1054159 non-null  int64
#  9   List Year         1054159 non-null  int64
#  10  Date Recorded     1054157 non-null  object
#  11  Town              1054159 non-null  object
#  12  Address           1054108 non-null  object
#  13  Assessed Value    1054159 non-null  int64
#  14  Sale Amount       1054159 non-null  float64
#  15  Sales Ratio       1054159 non-null  float64
#  16  Property Type     671713 non-null   object
#  17  Residential Type  660275 non-null   object
#  18  Non Use Code      302242 non-null   object
#  19  Assessor Remarks  161472 non-null   object
#  20  OPM remarks       11564 non-null    object
#  21  Location          254643 non-null   object
#  22  Counties          252797 non-null   float64
#  23  Zip Code          254626 non-null   float64
#  24  Town Index        253923 non-null   float64
#  25  Planning Regions  253923 non-null   float64
# dtypes: float64(8), int64(6), object(12)
# memory usage: 209.1+ MB

# %%
real_est.head()
# Out:
#                   sid                                    id  position  \
# 0  row-nct8~wv6h_sher  00000000-0000-0000-7C41-6C8A4092F57B         0
# 1  row-2y35-9qqi_7hpn  00000000-0000-0000-A402-71ABE687D103         0
# 2  row-vd9u~7ew8-3ghk  00000000-0000-0000-1CA7-B48011B80E7F         0
# 3  row-g9u8-j5iy~38bh  00000000-0000-0000-44D9-FD3ABE7FAD53         0
# 4  row-swq3~sutf_4mer  00000000-0000-0000-E5B6-CD8A9DCC0E5C         0
#
#    created_at  created_meta  updated_at  updated_meta meta  Serial Number  \
# 0  1666269278           NaN  1666269297           NaN  { }        2020177
# 1  1666269278           NaN  1666269297           NaN  { }        2020225
# 2  1666269278           NaN  1666269297           NaN  { }        2020348
# 3  1666269278           NaN  1666269297           NaN  { }        2020090
# 4  1666269278           NaN  1666269297           NaN  { }         200500
#
#    List Year  ... Property Type Residential Type Non Use Code  \
# 0       2020  ...   Residential    Single Family          NaN
# 1       2020  ...   Residential     Three Family          NaN
# 2       2020  ...    Commercial              NaN          NaN
# 3       2020  ...   Residential       Two Family          NaN
# 4       2020  ...   Residential    Single Family          NaN
#
#    Assessor Remarks  OPM remarks                    Location Counties  \
# 0               NaN          NaN  POINT (-73.06822 41.35014)   1044.0
# 1               NaN          NaN                         NaN      NaN
# 2               NaN          NaN                         NaN      NaN
# 3               NaN          NaN                         NaN      NaN
# 4               NaN          NaN                         NaN      NaN
#
#   Zip Code Town Index Planning Regions
# 0    102.0        2.0              4.0
# 1      NaN        NaN              NaN
# 2      NaN        NaN              NaN
# 3      NaN        NaN              NaN
# 4      NaN        NaN              NaN
#
# [5 rows x 26 columns]

# %%
real_est_cleaned = real_est.copy()

# %%
real_est_cleaned.columns
# Out:
# Index(['sid', 'id', 'position', 'created_at', 'created_meta', 'updated_at',
#        'updated_meta', 'meta', 'Serial Number', 'List Year', 'Date Recorded',
#        'Town', 'Address', 'Assessed Value', 'Sale Amount', 'Sales Ratio',
#        'Property Type', 'Residential Type', 'Non Use Code', 'Assessor Remarks',
#        'OPM remarks', 'Location', 'Counties', 'Zip Code', 'Town Index',
#        'Planning Regions'],
#       dtype='object')

# %%
meta_data = ['sid', 'id', 'position', 'created_at', 'created_meta', 'updated_at', 'updated_meta', 'meta', 'Counties', 'Zip Code', 'Town Index',
       'Planning Regions']

# %%
real_est_cleaned.drop(columns=meta_data, inplace=True)

# %%
real_est_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054159 entries, 0 to 1054158
# Data columns (total 14 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Serial Number     1054159 non-null  int64
#  1   List Year         1054159 non-null  int64
#  2   Date Recorded     1054157 non-null  object
#  3   Town              1054159 non-null  object
#  4   Address           1054108 non-null  object
#  5   Assessed Value    1054159 non-null  int64
#  6   Sale Amount       1054159 non-null  float64
#  7   Sales Ratio       1054159 non-null  float64
#  8   Property Type     671713 non-null   object
#  9   Residential Type  660275 non-null   object
#  10  Non Use Code      302242 non-null   object
#  11  Assessor Remarks  161472 non-null   object
#  12  OPM remarks       11564 non-null    object
#  13  Location          254643 non-null   object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 112.6+ MB

# %%
real_est_cleaned.head(10)
# Out:
#    Serial Number  List Year        Date Recorded          Town  \
# 0        2020177       2020  2021-04-14T00:00:00       Ansonia
# 1        2020225       2020  2021-05-26T00:00:00       Ansonia
# 2        2020348       2020  2021-09-13T00:00:00       Ansonia
# 3        2020090       2020  2020-12-14T00:00:00       Ansonia
# 4         200500       2020  2021-09-07T00:00:00          Avon
# 5         200121       2020  2020-12-15T00:00:00          Avon
# 6          20058       2020  2021-06-01T00:00:00   Barkhamsted
# 7         200046       2020  2021-01-25T00:00:00  Beacon Falls
# 8         200016       2020  2020-11-13T00:00:00  Beacon Falls
# 9        2020360       2020  2021-08-10T00:00:00        Berlin
#
#             Address  Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 0     323 BEAVER ST          133000     248400.0     0.535400   Residential
# 1    152 JACKSON ST          110500     239900.0     0.460600   Residential
# 2   230 WAKELEE AVE          150500     325000.0     0.463000    Commercial
# 3       57 PLATT ST          127400     202500.0     0.629100   Residential
# 4      245 NEW ROAD          217640     400000.0     0.544100   Residential
# 5      63 NORTHGATE          528490     775000.0     0.681900   Residential
# 6  46 RATLUM MTN RD          203530     415000.0     0.490434   Residential
# 7     34 LASKY ROAD          158030     243000.0     0.650300   Residential
# 8      9 AVON COURT           65590     100000.0     0.655900   Residential
# 9   94 PERCIVAL AVE          140600     190790.0     0.736900   Residential
#
#   Residential Type Non Use Code                   Assessor Remarks  \
# 0    Single Family          NaN                                NaN
# 1     Three Family          NaN                                NaN
# 2              NaN          NaN                                NaN
# 3       Two Family          NaN                                NaN
# 4    Single Family          NaN                                NaN
# 5    Single Family          NaN                                NaN
# 6    Single Family          NaN  2003 COLONIAL, 2140 SFLA, 2.99 AC
# 7    Single Family          NaN                                NaN
# 8            Condo          NaN                                NaN
# 9    Single Family          NaN                                NaN
#
#   OPM remarks                    Location
# 0         NaN  POINT (-73.06822 41.35014)
# 1         NaN                         NaN
# 2         NaN                         NaN
# 3         NaN                         NaN
# 4         NaN                         NaN
# 5         NaN  POINT (-72.89675 41.79445)
# 6         NaN                         NaN
# 7         NaN                         NaN
# 8         NaN                         NaN
# 9         NaN                         NaN

# %%
real_est_cleaned.dtypes
# Out:
# Serial Number         int64
# List Year             int64
# Date Recorded        object
# Town                 object
# Address              object
# Assessed Value        int64
# Sale Amount         float64
# Sales Ratio         float64
# Property Type        object
# Residential Type     object
# Non Use Code         object
# Assessor Remarks     object
# OPM remarks          object
# Location             object
# dtype: object

# %%
real_est_cleaned.isnull().sum()
# Out:
# Serial Number             0
# List Year                 0
# Date Recorded             2
# Town                      0
# Address                  51
# Assessed Value            0
# Sale Amount               0
# Sales Ratio               0
# Property Type        382446
# Residential Type     393884
# Non Use Code         751917
# Assessor Remarks     892687
# OPM remarks         1042595
# Location             799516
# dtype: int64

# %%
#check for duplicates
serial_number_counts = real_est_cleaned['Serial Number'].value_counts()
print("Counts of each serial number:")
print(serial_number_counts)
# Out:
# Counts of each serial number:
# Serial Number
# 10018        172
# 10002        172
# 10010        172
# 10015        171
# 10029        171
#             ...
# 1501564        1
# 1500492        1
# 1501533        1
# 1500584        1
# 210500004      1
# Name: count, Length: 90873, dtype: int64

# %%
serial_number_10018 = real_est_cleaned[real_est_cleaned['Serial Number'] == 10018]
print(serial_number_10018.head(10))
# Out:
#        Serial Number  List Year        Date Recorded         Town  \
# 69032          10018       2001  2001-12-04T00:00:00      Ashford
# 69956          10018       2001  2001-10-24T00:00:00      Ansonia
# 70916          10018       2001  2002-01-17T00:00:00       Bozrah
# 70981          10018       2001  2001-10-09T00:00:00   Manchester
# 71631          10018       2001  2001-10-31T00:00:00  East Granby
# 71902          10018       2001  2001-12-03T00:00:00       Bolton
# 72028          10018       2001  2001-10-02T00:00:00       Hamden
# 72938          10018       2001  2001-10-29T00:00:00     Brooklyn
# 73196          10018       2001  2002-01-17T00:00:00      Hampton
# 73413          10018       2001  2001-11-08T00:00:00   Burlington
#
#                   Address  Assessed Value  Sale Amount  Sales Ratio  \
# 69032  181 WESTFORD HL RD           77360     109822.0     0.704413
# 69956   84-86 CLIFTON AVE           99190     127000.0     0.781024
# 70916           BOZRAH ST              70       1500.0     0.046667
# 70981       136 SCHOOL ST           98000     106000.0     0.924528
# 71631     19 HORSESHOE DR          101600     185900.0     0.546530
# 71902         6 HEBRON RD          117790     235000.0     0.501234
# 72028        15 WILMOT RD           71120     123000.0     0.578211
# 72938   190 CANTERBURY RD           83160      45000.0     1.848000
# 73196         222 MAIN ST           77120     140000.0     0.550857
# 73413        7 SUNSET RDG          147140     345000.0     0.426493
#
#       Property Type Residential Type Non Use Code Assessor Remarks  \
# 69032           NaN              NaN           25              NaN
# 69956           NaN              NaN          NaN              NaN
# 70916           NaN              NaN           12              NaN
# 70981           NaN              NaN          NaN              NaN
# 71631           NaN              NaN          NaN              NaN
# 71902           NaN              NaN          NaN              NaN
# 72028           NaN              NaN          NaN              NaN
# 72938           NaN              NaN            1              NaN
# 73196           NaN              NaN          NaN              NaN
# 73413           NaN              NaN            1              NaN
#
#       OPM remarks                    Location
# 69032         NaN                         NaN
# 69956         NaN                         NaN
# 70916         NaN                         NaN
# 70981         NaN                         NaN
# 71631         NaN                         NaN
# 71902         NaN                         NaN
# 72028         NaN                         NaN
# 72938         NaN  POINT (-71.95326 41.77504)
# 73196         NaN                         NaN
# 73413         NaN  POINT (-72.92232 41.73385)

# %%
num_duplicate_rows = real_est_cleaned.duplicated().sum()
print(num_duplicate_rows)
#no rows are duplicated
# Out:
# 0

# %%
#drop columns 'Serial Number', 'Non Use Code', 'Assessor Remarks','OPM remarks', 'Location'
#drop NA for Address columns and Date Recorded
#most frequent for 'Property Type' and "Residential Type"

# %%
from sklearn.impute import SimpleImputer

# %%
imp_most_freq = SimpleImputer(strategy='most_frequent')

# %%
real_est_cleaned['Property Type'] = imp_most_freq.fit_transform(df['Property Type'].values.reshape(-1,1))[:,0]

# %%
real_est_cleaned['Residential Type'] = imp_most_freq.fit_transform(df['Residential Type'].values.reshape(-1,1))[:,0]

# %%
real_est_cleaned = real_est_cleaned.dropna(subset=['Address'])

# %%
real_est_cleaned = real_est_cleaned.dropna(subset=['Date Recorded'])

# %%
column_to_drop = ['Serial Number','Non Use Code', 'Assessor Remarks','OPM remarks', 'Location']

# %%
real_est_cleaned.drop(columns=column_to_drop, inplace=True)

# %%
real_est_cleaned.isnull().sum()
# Out:
# List Year           0
# Date Recorded       0
# Town                0
# Address             0
# Assessed Value      0
# Sale Amount         0
# Sales Ratio         0
# Property Type       0
# Residential Type    0
# dtype: int64

# %%
real_est_cleaned.head(25)
# Out:
#     List Year        Date Recorded          Town                     Address  \
# 0        2020  2021-04-14T00:00:00       Ansonia               323 BEAVER ST
# 1        2020  2021-05-26T00:00:00       Ansonia              152 JACKSON ST
# 2        2020  2021-09-13T00:00:00       Ansonia             230 WAKELEE AVE
# 3        2020  2020-12-14T00:00:00       Ansonia                 57 PLATT ST
# 4        2020  2021-09-07T00:00:00          Avon                245 NEW ROAD
# 5        2020  2020-12-15T00:00:00          Avon                63 NORTHGATE
# 6        2020  2021-06-01T00:00:00   Barkhamsted            46 RATLUM MTN RD
# 7        2020  2021-01-25T00:00:00  Beacon Falls               34 LASKY ROAD
# 8        2020  2020-11-13T00:00:00  Beacon Falls                9 AVON COURT
# 9        2020  2021-08-10T00:00:00        Berlin             94 PERCIVAL AVE
# 10       2020  2021-04-21T00:00:00        Bethel            16 OXFORD STREET
# 11       2020  2021-06-17T00:00:00        Bethel    1308 LEXINGTON BOULEVARD
# 12       2020  2021-07-21T00:00:00        Bethel         10 CASTLE HILL ROAD
# 13       2020  2020-11-25T00:00:00        Bethel           8 BLACKMAN AVENUE
# 14       2020  2020-10-21T00:00:00     Bethlehem            34 HIGHLAND ROAD
# 15       2020  2021-05-10T00:00:00        Bolton            39 STONEHEDGE LN
# 16       2020  2021-02-22T00:00:00      Branford  49 ROSE ST TOWERS UNIT 402
# 17       2020  2021-04-08T00:00:00      Branford                 460 MAIN ST
# 18       2020  2021-04-23T00:00:00      Branford               24 COLLINS DR
# 19       2020  2021-05-18T00:00:00      Branford                61 PALMER RD
# 20       2020  2020-12-11T00:00:00      Branford                  3 GROVE CT
# 21       2020  2020-12-18T00:00:00      Branford                69 CHURCH ST
# 22       2020  2021-09-22T00:00:00       Bristol                118 MOODY ST
# 23       2020  2021-09-23T00:00:00       Bristol            103 BUTTERNUT LN
# 24       2020  2021-01-15T00:00:00       Bristol         MILL POND DR LOT 50
#
#     Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type
# 0           133000     248400.0     0.535400   Residential    Single Family
# 1           110500     239900.0     0.460600   Residential     Three Family
# 2           150500     325000.0     0.463000    Commercial    Single Family
# 3           127400     202500.0     0.629100   Residential       Two Family
# 4           217640     400000.0     0.544100   Residential    Single Family
# 5           528490     775000.0     0.681900   Residential    Single Family
# 6           203530     415000.0     0.490434   Residential    Single Family
# 7           158030     243000.0     0.650300   Residential    Single Family
# 8            65590     100000.0     0.655900   Residential            Condo
# 9           140600     190790.0     0.736900   Residential    Single Family
# 10          170800     307000.0     0.556300   Residential    Single Family
# 11          195300     365000.0     0.535000   Residential            Condo
# 12          219870     325000.0     0.676500   Residential    Single Family
# 13          264040     445000.0     0.593300   Residential       Two Family
# 14           82000     106000.0     0.773500   Residential    Single Family
# 15          189400     273750.0     0.691800   Residential    Single Family
# 16           97800     147000.0     0.665300   Residential            Condo
# 17          180500     355000.0     0.508400   Residential       Two Family
# 18          147000     290000.0     0.506800   Residential    Single Family
# 19          219900     460000.0     0.478000   Residential    Single Family
# 20           43400      86501.0     0.501700   Residential            Condo
# 21          200900     320000.0     0.627800   Residential       Two Family
# 22          117950     240000.0     0.491400   Residential    Single Family
# 23           61950     129900.0     0.476900   Residential            Condo
# 24           47530     100000.0     0.475300   Vacant Land    Single Family

# %%
real_est_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1054108 entries, 0 to 1054158
# Data columns (total 9 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   List Year         1054108 non-null  int64
#  1   Date Recorded     1054108 non-null  object
#  2   Town              1054108 non-null  object
#  3   Address           1054108 non-null  object
#  4   Assessed Value    1054108 non-null  int64
#  5   Sale Amount       1054108 non-null  float64
#  6   Sales Ratio       1054108 non-null  float64
#  7   Property Type     1054108 non-null  object
#  8   Residential Type  1054108 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 80.4+ MB

# %%
num_duplicate_rows = real_est_cleaned.duplicated().sum()
print(num_duplicate_rows)
# Out:
# 8728

# %%
real_est_cleaned.head(25)
# Out:
#     List Year        Date Recorded          Town                     Address  \
# 0        2020  2021-04-14T00:00:00       Ansonia               323 BEAVER ST
# 1        2020  2021-05-26T00:00:00       Ansonia              152 JACKSON ST
# 2        2020  2021-09-13T00:00:00       Ansonia             230 WAKELEE AVE
# 3        2020  2020-12-14T00:00:00       Ansonia                 57 PLATT ST
# 4        2020  2021-09-07T00:00:00          Avon                245 NEW ROAD
# 5        2020  2020-12-15T00:00:00          Avon                63 NORTHGATE
# 6        2020  2021-06-01T00:00:00   Barkhamsted            46 RATLUM MTN RD
# 7        2020  2021-01-25T00:00:00  Beacon Falls               34 LASKY ROAD
# 8        2020  2020-11-13T00:00:00  Beacon Falls                9 AVON COURT
# 9        2020  2021-08-10T00:00:00        Berlin             94 PERCIVAL AVE
# 10       2020  2021-04-21T00:00:00        Bethel            16 OXFORD STREET
# 11       2020  2021-06-17T00:00:00        Bethel    1308 LEXINGTON BOULEVARD
# 12       2020  2021-07-21T00:00:00        Bethel         10 CASTLE HILL ROAD
# 13       2020  2020-11-25T00:00:00        Bethel           8 BLACKMAN AVENUE
# 14       2020  2020-10-21T00:00:00     Bethlehem            34 HIGHLAND ROAD
# 15       2020  2021-05-10T00:00:00        Bolton            39 STONEHEDGE LN
# 16       2020  2021-02-22T00:00:00      Branford  49 ROSE ST TOWERS UNIT 402
# 17       2020  2021-04-08T00:00:00      Branford                 460 MAIN ST
# 18       2020  2021-04-23T00:00:00      Branford               24 COLLINS DR
# 19       2020  2021-05-18T00:00:00      Branford                61 PALMER RD
# 20       2020  2020-12-11T00:00:00      Branford                  3 GROVE CT
# 21       2020  2020-12-18T00:00:00      Branford                69 CHURCH ST
# 22       2020  2021-09-22T00:00:00       Bristol                118 MOODY ST
# 23       2020  2021-09-23T00:00:00       Bristol            103 BUTTERNUT LN
# 24       2020  2021-01-15T00:00:00       Bristol         MILL POND DR LOT 50
#
#     Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type
# 0           133000     248400.0     0.535400   Residential    Single Family
# 1           110500     239900.0     0.460600   Residential     Three Family
# 2           150500     325000.0     0.463000    Commercial    Single Family
# 3           127400     202500.0     0.629100   Residential       Two Family
# 4           217640     400000.0     0.544100   Residential    Single Family
# 5           528490     775000.0     0.681900   Residential    Single Family
# 6           203530     415000.0     0.490434   Residential    Single Family
# 7           158030     243000.0     0.650300   Residential    Single Family
# 8            65590     100000.0     0.655900   Residential            Condo
# 9           140600     190790.0     0.736900   Residential    Single Family
# 10          170800     307000.0     0.556300   Residential    Single Family
# 11          195300     365000.0     0.535000   Residential            Condo
# 12          219870     325000.0     0.676500   Residential    Single Family
# 13          264040     445000.0     0.593300   Residential       Two Family
# 14           82000     106000.0     0.773500   Residential    Single Family
# 15          189400     273750.0     0.691800   Residential    Single Family
# 16           97800     147000.0     0.665300   Residential            Condo
# 17          180500     355000.0     0.508400   Residential       Two Family
# 18          147000     290000.0     0.506800   Residential    Single Family
# 19          219900     460000.0     0.478000   Residential    Single Family
# 20           43400      86501.0     0.501700   Residential            Condo
# 21          200900     320000.0     0.627800   Residential       Two Family
# 22          117950     240000.0     0.491400   Residential    Single Family
# 23           61950     129900.0     0.476900   Residential            Condo
# 24           47530     100000.0     0.475300   Vacant Land    Single Family

# %%
real_est_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1054108 entries, 0 to 1054158
# Data columns (total 9 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   List Year         1054108 non-null  int64
#  1   Date Recorded     1054108 non-null  object
#  2   Town              1054108 non-null  object
#  3   Address           1054108 non-null  object
#  4   Assessed Value    1054108 non-null  int64
#  5   Sale Amount       1054108 non-null  float64
#  6   Sales Ratio       1054108 non-null  float64
#  7   Property Type     1054108 non-null  object
#  8   Residential Type  1054108 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 80.4+ MB

# %%
num_duplicate_rows_Transact = real_est_cleaned.duplicated().sum()
print(num_duplicate_rows)
# Out:
# 8728

# %%
real_est_cleaned.head(10)
# Out:
#    List Year        Date Recorded          Town           Address  \
# 0       2020  2021-04-14T00:00:00       Ansonia     323 BEAVER ST
# 1       2020  2021-05-26T00:00:00       Ansonia    152 JACKSON ST
# 2       2020  2021-09-13T00:00:00       Ansonia   230 WAKELEE AVE
# 3       2020  2020-12-14T00:00:00       Ansonia       57 PLATT ST
# 4       2020  2021-09-07T00:00:00          Avon      245 NEW ROAD
# 5       2020  2020-12-15T00:00:00          Avon      63 NORTHGATE
# 6       2020  2021-06-01T00:00:00   Barkhamsted  46 RATLUM MTN RD
# 7       2020  2021-01-25T00:00:00  Beacon Falls     34 LASKY ROAD
# 8       2020  2020-11-13T00:00:00  Beacon Falls      9 AVON COURT
# 9       2020  2021-08-10T00:00:00        Berlin   94 PERCIVAL AVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type
# 0          133000     248400.0     0.535400   Residential    Single Family
# 1          110500     239900.0     0.460600   Residential     Three Family
# 2          150500     325000.0     0.463000    Commercial    Single Family
# 3          127400     202500.0     0.629100   Residential       Two Family
# 4          217640     400000.0     0.544100   Residential    Single Family
# 5          528490     775000.0     0.681900   Residential    Single Family
# 6          203530     415000.0     0.490434   Residential    Single Family
# 7          158030     243000.0     0.650300   Residential    Single Family
# 8           65590     100000.0     0.655900   Residential            Condo
# 9          140600     190790.0     0.736900   Residential    Single Family

# %%
real_est_cleaned.isnull().sum()
# Out:
# List Year           0
# Date Recorded       0
# Town                0
# Address             0
# Assessed Value      0
# Sale Amount         0
# Sales Ratio         0
# Property Type       0
# Residential Type    0
# dtype: int64

# %%
has_decimal = (real_est_cleaned['Sale Amount'].dropna() % 1 != 0).any()

print(f"Are there any values with digits after the decimal point? {has_decimal}")
# Out:
# Are there any values with digits after the decimal point? True

# %%
real_est_cleaned.head(10)
# Out:
#    List Year        Date Recorded          Town           Address  \
# 0       2020  2021-04-14T00:00:00       Ansonia     323 BEAVER ST
# 1       2020  2021-05-26T00:00:00       Ansonia    152 JACKSON ST
# 2       2020  2021-09-13T00:00:00       Ansonia   230 WAKELEE AVE
# 3       2020  2020-12-14T00:00:00       Ansonia       57 PLATT ST
# 4       2020  2021-09-07T00:00:00          Avon      245 NEW ROAD
# 5       2020  2020-12-15T00:00:00          Avon      63 NORTHGATE
# 6       2020  2021-06-01T00:00:00   Barkhamsted  46 RATLUM MTN RD
# 7       2020  2021-01-25T00:00:00  Beacon Falls     34 LASKY ROAD
# 8       2020  2020-11-13T00:00:00  Beacon Falls      9 AVON COURT
# 9       2020  2021-08-10T00:00:00        Berlin   94 PERCIVAL AVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type
# 0          133000     248400.0     0.535400   Residential    Single Family
# 1          110500     239900.0     0.460600   Residential     Three Family
# 2          150500     325000.0     0.463000    Commercial    Single Family
# 3          127400     202500.0     0.629100   Residential       Two Family
# 4          217640     400000.0     0.544100   Residential    Single Family
# 5          528490     775000.0     0.681900   Residential    Single Family
# 6          203530     415000.0     0.490434   Residential    Single Family
# 7          158030     243000.0     0.650300   Residential    Single Family
# 8           65590     100000.0     0.655900   Residential            Condo
# 9          140600     190790.0     0.736900   Residential    Single Family

# %%
unique_property_types = real_est_cleaned['Property Type'].unique()

print("Unique values in 'Property Type':")
print(unique_property_types)
# Out:
# Unique values in 'Property Type':
# ['Residential' 'Commercial' 'Vacant Land' 'Public Utility' 'Apartments'
#  'Single Family' 'Industrial' 'Condo' 'Two Family' 'Three Family'
#  'Four Family']

# %%
#creating dim_property_type dimention

#mapping dictionary
propertytype_mapping = {
    'Residential': 1,
    'Commercial': 2,
    'Vacant Land': 3,
    'Public Utility': 4,
    'Apartments': 5,
    'Single Family': 6,
    'Industrial': 7,
    'Condo': 8,
    'Two Family': 9,
    'Three Family': 10,
    'Four Family': 11
}

unique_propertytype = real_est_cleaned['Property Type'].unique()

# Converting the array of unique values into a DataFrame
unique_propertytype_df = pd.DataFrame(unique_propertytype, columns=['Property Type'])

# Applying the mapping to create a new column with descriptions
unique_propertytype_df['propertytype_id'] = unique_propertytype_df['Property Type'].map(propertytype_mapping)
unique_propertytype_df.rename(columns={'Property Type': 'propertytype'}, inplace=True)
unique_propertytype_df = unique_propertytype_df[unique_propertytype_df['propertytype'] != '<NA>']

unique_propertytype_df = unique_propertytype_df[['propertytype_id', 'propertytype']]

unique_propertytype_df
# Out:
#     propertytype_id    propertytype
# 0                 1     Residential
# 1                 2      Commercial
# 2                 3     Vacant Land
# 3                 4  Public Utility
# 4                 5      Apartments
# 5                 6   Single Family
# 6                 7      Industrial
# 7                 8           Condo
# 8                 9      Two Family
# 9                10    Three Family
# 10               11     Four Family

# %%
unique_residential_types = real_est_cleaned['Residential Type'].unique()

print("Unique values in 'Residential Type':")
print(unique_residential_types)
# Out:
# Unique values in 'Residential Type':
# ['Single Family' 'Three Family' 'Two Family' 'Condo' 'Four Family']

# %%
#creating dim_residential_type dimention

#mapping dictionary
residentialtype_mapping = {
    'Single Family': 1,
    'Three Family': 2,
    'Two Family': 3,
    'Condo': 4,
    'Four Family': 5
}
unique_residentialtype = real_est_cleaned['Residential Type'].unique()

# Converting the array of unique values into a DataFrame
unique_residentialtype_df = pd.DataFrame(unique_residentialtype, columns=['Residential Type'])

# Applying the mapping to create a new column with descriptions
unique_residentialtype_df['residentialtype_id'] = unique_residentialtype_df['Residential Type'].map(residentialtype_mapping)
unique_residentialtype_df.rename(columns={'Residential Type': 'residential_type'}, inplace=True)
unique_residentialtype_df = unique_residentialtype_df[unique_residentialtype_df['residential_type'] != '<NA>']

unique_residentialtype_df = unique_residentialtype_df[['residentialtype_id', 'residential_type']]

unique_residentialtype_df
# Out:
#    residentialtype_id residential_type
# 0                   1    Single Family
# 1                   2     Three Family
# 2                   3       Two Family
# 3                   4            Condo
# 4                   5      Four Family

# %%
# Rename the columns to uppercase
#unique_residentialtype_df.rename(columns={'residentialtype_id': 'RESIDENTIALTYPE_ID', 'residential_type': 'RESIDENTIAL_TYPE'}, inplace=True)

# %%
# creating dim_location dimension
unique_locations = real_est_cleaned[['Town', 'Address']].drop_duplicates()
unique_locations['location_id'] = range(1, len(unique_locations) + 1)
unique_locations.rename(columns={'Town': 'town', 'Address': 'address'}, inplace=True)
unique_locations = unique_locations[['location_id', 'town', 'address']]

# %%
print(unique_locations)
# Out:
#          location_id           town                    address
# 0                  1        Ansonia              323 BEAVER ST
# 1                  2        Ansonia             152 JACKSON ST
# 2                  3        Ansonia            230 WAKELEE AVE
# 3                  4        Ansonia                57 PLATT ST
# 4                  5           Avon               245 NEW ROAD
# ...              ...            ...                        ...
# 1054150       797579  West Hartford           97 MOHEGAN DRIVE
# 1054152       797580       Westport            140 EASTON ROAD
# 1054153       797581   Wethersfield              181 FOREST DR
# 1054155       797582       Woodbury  89 TAMARACK LANR UNIT 89A
# 1054156       797583       Woodbury         69 BACON POND ROAD
#
# [797583 rows x 3 columns]

# %%
# Convert the 'Date Recorded' column to datetime
df['Date Recorded'] = pd.to_datetime(df['Date Recorded'], errors='coerce')

# Now find the minimum and maximum dates
start_date = df['Date Recorded'].min()
end_date = df['Date Recorded'].max()

# %%
start_date_y = df['List Year'].min()
end_date_y = df['List Year'].max()

# %%
print(start_date_y)
print(end_date_y)
# Out:
# 2001
# 2021

# %%
print(start_date)
# Out:
# 1999-04-05 00:00:00

# %%
print(end_date)
# Out:
# 2022-09-30 00:00:00

# %%
# Function to calculate the week of the month for a given date
def week_of_month(dt):
    year = dt.year
    month = dt.month
    day = dt.day

    cal = calendar.monthcalendar(year, month)
    week_number = (day - 1) // 7 + 1
    return week_number

# Define start and end dates
start_date = pd.to_datetime('1999-04-05')
end_date = pd.to_datetime('2022-09-30')

# Create a DataFrame for the date dimension
date_dimension = pd.DataFrame({'date': pd.date_range(start_date, end_date, freq='D')})

# Extract attributes
date_dimension['year'] = date_dimension['date'].dt.year
date_dimension['quarter'] = date_dimension['date'].dt.quarter
date_dimension['month'] = date_dimension['date'].dt.month
date_dimension['monthname'] = date_dimension['date'].dt.strftime('%B')
date_dimension['day'] = date_dimension['date'].dt.day
date_dimension['dayname'] = date_dimension['date'].dt.strftime('%A')
date_dimension['date_iso_format'] = date_dimension['date'].apply(lambda x: x.date().isoformat())
date_dimension['date_id'] = date_dimension['date'].dt.strftime('%Y%m%d')
date_dimension['date_original_format'] = date_dimension['date'].dt.strftime('%Y-%m-%d')

# Add week of the month and week of the year
date_dimension['weekofMonth'] = date_dimension['date'].apply(week_of_month)
date_dimension['weekoftheyear'] = date_dimension['date'].dt.strftime('%U')

# Reorder columns
new_order = ['date_id', 'date_original_format', 'date_iso_format', 'year', 'quarter', 'month', 'day', 'monthname', 'dayname', 'weekoftheyear']
date_dimension = date_dimension[new_order]

print(date_dimension.head(25))
# Out:
#      date_id date_original_format date_iso_format  year  quarter  month  day  \
# 0   19990405           1999-04-05      1999-04-05  1999        2      4    5
# 1   19990406           1999-04-06      1999-04-06  1999        2      4    6
# 2   19990407           1999-04-07      1999-04-07  1999        2      4    7
# 3   19990408           1999-04-08      1999-04-08  1999        2      4    8
# 4   19990409           1999-04-09      1999-04-09  1999        2      4    9
# 5   19990410           1999-04-10      1999-04-10  1999        2      4   10
# 6   19990411           1999-04-11      1999-04-11  1999        2      4   11
# 7   19990412           1999-04-12      1999-04-12  1999        2      4   12
# 8   19990413           1999-04-13      1999-04-13  1999        2      4   13
# 9   19990414           1999-04-14      1999-04-14  1999        2      4   14
# 10  19990415           1999-04-15      1999-04-15  1999        2      4   15
# 11  19990416           1999-04-16      1999-04-16  1999        2      4   16
# 12  19990417           1999-04-17      1999-04-17  1999        2      4   17
# 13  19990418           1999-04-18      1999-04-18  1999        2      4   18
# 14  19990419           1999-04-19      1999-04-19  1999        2      4   19
# 15  19990420           1999-04-20      1999-04-20  1999        2      4   20
# 16  19990421           1999-04-21      1999-04-21  1999        2      4   21
# 17  19990422           1999-04-22      1999-04-22  1999        2      4   22
# 18  19990423           1999-04-23      1999-04-23  1999        2      4   23
# 19  19990424           1999-04-24      1999-04-24  1999        2      4   24
# 20  19990425           1999-04-25      1999-04-25  1999        2      4   25
# 21  19990426           1999-04-26      1999-04-26  1999        2      4   26
# 22  19990427           1999-04-27      1999-04-27  1999        2      4   27
# 23  19990428           1999-04-28      1999-04-28  1999        2      4   28
# 24  19990429           1999-04-29      1999-04-29  1999        2      4   29
#
#    monthname    dayname weekoftheyear
# 0      April     Monday            14
# 1      April    Tuesday            14
# 2      April  Wednesday            14
# 3      April   Thursday            14
# 4      April     Friday            14
# 5      April   Saturday            14
# 6      April     Sunday            15
# 7      April     Monday            15
# 8      April    Tuesday            15
# 9      April  Wednesday            15
# 10     April   Thursday            15
# 11     April     Friday            15
# 12     April   Saturday            15
# 13     April     Sunday            16
# 14     April     Monday            16
# 15     April    Tuesday            16
# 16     April  Wednesday            16
# 17     April   Thursday            16
# 18     April     Friday            16
# 19     April   Saturday            16
# 20     April     Sunday            17
# 21     April     Monday            17
# 22     April    Tuesday            17
# 23     April  Wednesday            17
# 24     April   Thursday            17

# %%
date_dimension.tail(25)
# Out:
#        date_id date_original_format date_iso_format  year  quarter  month  \
# 8555  20220906           2022-09-06      2022-09-06  2022        3      9
# 8556  20220907           2022-09-07      2022-09-07  2022        3      9
# 8557  20220908           2022-09-08      2022-09-08  2022        3      9
# 8558  20220909           2022-09-09      2022-09-09  2022        3      9
# 8559  20220910           2022-09-10      2022-09-10  2022        3      9
# 8560  20220911           2022-09-11      2022-09-11  2022        3      9
# 8561  20220912           2022-09-12      2022-09-12  2022        3      9
# 8562  20220913           2022-09-13      2022-09-13  2022        3      9
# 8563  20220914           2022-09-14      2022-09-14  2022        3      9
# 8564  20220915           2022-09-15      2022-09-15  2022        3      9
# 8565  20220916           2022-09-16      2022-09-16  2022        3      9
# 8566  20220917           2022-09-17      2022-09-17  2022        3      9
# 8567  20220918           2022-09-18      2022-09-18  2022        3      9
# 8568  20220919           2022-09-19      2022-09-19  2022        3      9
# 8569  20220920           2022-09-20      2022-09-20  2022        3      9
# 8570  20220921           2022-09-21      2022-09-21  2022        3      9
# 8571  20220922           2022-09-22      2022-09-22  2022        3      9
# 8572  20220923           2022-09-23      2022-09-23  2022        3      9
# 8573  20220924           2022-09-24      2022-09-24  2022        3      9
# 8574  20220925           2022-09-25      2022-09-25  2022        3      9
# 8575  20220926           2022-09-26      2022-09-26  2022        3      9
# 8576  20220927           2022-09-27      2022-09-27  2022        3      9
# 8577  20220928           2022-09-28      2022-09-28  2022        3      9
# 8578  20220929           2022-09-29      2022-09-29  2022        3      9
# 8579  20220930           2022-09-30      2022-09-30  2022        3      9
#
#       day  monthname    dayname weekoftheyear
# 8555    6  September    Tuesday            36
# 8556    7  September  Wednesday            36
# 8557    8  September   Thursday            36
# 8558    9  September     Friday            36
# 8559   10  September   Saturday            36
# 8560   11  September     Sunday            37
# 8561   12  September     Monday            37
# 8562   13  September    Tuesday            37
# 8563   14  September  Wednesday            37
# 8564   15  September   Thursday            37
# 8565   16  September     Friday            37
# 8566   17  September   Saturday            37
# 8567   18  September     Sunday            38
# 8568   19  September     Monday            38
# 8569   20  September    Tuesday            38
# 8570   21  September  Wednesday            38
# 8571   22  September   Thursday            38
# 8572   23  September     Friday            38
# 8573   24  September   Saturday            38
# 8574   25  September     Sunday            39
# 8575   26  September     Monday            39
# 8576   27  September    Tuesday            39
# 8577   28  September  Wednesday            39
# 8578   29  September   Thursday            39
# 8579   30  September     Friday            39

# %%
real_est_cleaned.head()
# Out:
#    List Year        Date Recorded     Town          Address  Assessed Value  \
# 0       2020  2021-04-14T00:00:00  Ansonia    323 BEAVER ST          133000
# 1       2020  2021-05-26T00:00:00  Ansonia   152 JACKSON ST          110500
# 2       2020  2021-09-13T00:00:00  Ansonia  230 WAKELEE AVE          150500
# 3       2020  2020-12-14T00:00:00  Ansonia      57 PLATT ST          127400
# 4       2020  2021-09-07T00:00:00     Avon     245 NEW ROAD          217640
#
#    Sale Amount  Sales Ratio Property Type Residential Type
# 0     248400.0       0.5354   Residential    Single Family
# 1     239900.0       0.4606   Residential     Three Family
# 2     325000.0       0.4630    Commercial    Single Family
# 3     202500.0       0.6291   Residential       Two Family
# 4     400000.0       0.5441   Residential    Single Family

# %%
# Ensure 'Date Recorded' is in datetime format
real_est_cleaned['Date Recorded'] = pd.to_datetime(real_est_cleaned['Date Recorded'])

# Add a new column with the date in ISO format
real_est_cleaned['Date Recorded ISO'] = real_est_cleaned['Date Recorded'].dt.date.apply(lambda x: x.isoformat())

# %%
# Convert 'List Year' to string, add '-01-01', and then convert to datetime format
real_est_cleaned['List Year'] = pd.to_datetime(real_est_cleaned['List Year'].astype(str) + '-01-01')

# %%
# Assign 'residentialtype_id' to 'real_est_cleaned' DataFrame based on 'Residential Type'
real_est_cleaned['residentialtype_id'] = real_est_cleaned['Residential Type'].map(residentialtype_mapping)

# %%
# Assign 'propertytype_id' to 'real_est_cleaned' DataFrame based on 'Property Type'
real_est_cleaned['propertytype_id'] = real_est_cleaned['Property Type'].map(propertytype_mapping)

# %%
# Merge 'real_est_cleaned' with 'unique_locations' to assign 'location_id'
real_est_cleaned = pd.merge(real_est_cleaned, unique_locations, how='left', left_on=['Town', 'Address'], right_on=['town', 'address'])

# Drop the 'town' and 'address' columns as they are redundant
real_est_cleaned.drop(['town', 'address'], axis=1, inplace=True)

# %%
# Drop specified columns from 'real_est_cleaned' DataFrame
real_est_cleaned.drop(['Town', 'Address', 'Property Type', 'Residential Type'], axis=1, inplace=True)

# %%
real_est_cleaned.head()
# Out:
#    List Year Date Recorded  Assessed Value  Sale Amount  Sales Ratio  \
# 0 2020-01-01    2021-04-14          133000     248400.0       0.5354
# 1 2020-01-01    2021-05-26          110500     239900.0       0.4606
# 2 2020-01-01    2021-09-13          150500     325000.0       0.4630
# 3 2020-01-01    2020-12-14          127400     202500.0       0.6291
# 4 2020-01-01    2021-09-07          217640     400000.0       0.5441
#
#   Date Recorded ISO  residentialtype_id  propertytype_id  location_id
# 0        2021-04-14                   1                1            1
# 1        2021-05-26                   2                1            2
# 2        2021-09-13                   1                2            3
# 3        2020-12-14                   3                1            4
# 4        2021-09-07                   1                1            5

# %%
# Merge the two dataframes on 'Date Recorded ISO' in real_est_cleaned and 'date_iso_format' in date_dimension
merged_df = real_est_cleaned.merge(date_dimension, left_on='Date Recorded ISO', right_on='date_iso_format', how='left')

#Update the 'Date Recorded ISO' with 'date_id'
real_est_cleaned['Date Recorded ISO'] = merged_df['date_id']

# Verify the results
print(real_est_cleaned.head())
# Out:
#    List Year Date Recorded  Assessed Value  Sale Amount  Sales Ratio  \
# 0 2020-01-01    2021-04-14          133000     248400.0       0.5354
# 1 2020-01-01    2021-05-26          110500     239900.0       0.4606
# 2 2020-01-01    2021-09-13          150500     325000.0       0.4630
# 3 2020-01-01    2020-12-14          127400     202500.0       0.6291
# 4 2020-01-01    2021-09-07          217640     400000.0       0.5441
#
#   Date Recorded ISO  residentialtype_id  propertytype_id  location_id
# 0          20210414                   1                1            1
# 1          20210526                   2                1            2
# 2          20210913                   1                2            3
# 3          20201214                   3                1            4
# 4          20210907                   1                1            5

# %%
#date_dimension
date_dimension.head()
# Out:
#     date_id date_original_format date_iso_format  year  quarter  month  day  \
# 0  19990405           1999-04-05      1999-04-05  1999        2      4    5
# 1  19990406           1999-04-06      1999-04-06  1999        2      4    6
# 2  19990407           1999-04-07      1999-04-07  1999        2      4    7
# 3  19990408           1999-04-08      1999-04-08  1999        2      4    8
# 4  19990409           1999-04-09      1999-04-09  1999        2      4    9
#
#   monthname    dayname weekoftheyear
# 0     April     Monday            14
# 1     April    Tuesday            14
# 2     April  Wednesday            14
# 3     April   Thursday            14
# 4     April     Friday            14

# %%
#loc dim
unique_locations.head()
# Out:
#    location_id     town          address
# 0            1  Ansonia    323 BEAVER ST
# 1            2  Ansonia   152 JACKSON ST
# 2            3  Ansonia  230 WAKELEE AVE
# 3            4  Ansonia      57 PLATT ST
# 4            5     Avon     245 NEW ROAD

# %%
#facts_realestate
real_est_cleaned.head()
# Out:
#    List Year Date Recorded  Assessed Value  Sale Amount  Sales Ratio  \
# 0 2020-01-01    2021-04-14          133000     248400.0       0.5354
# 1 2020-01-01    2021-05-26          110500     239900.0       0.4606
# 2 2020-01-01    2021-09-13          150500     325000.0       0.4630
# 3 2020-01-01    2020-12-14          127400     202500.0       0.6291
# 4 2020-01-01    2021-09-07          217640     400000.0       0.5441
#
#   Date Recorded ISO  residentialtype_id  propertytype_id  location_id
# 0          20210414                   1                1            1
# 1          20210526                   2                1            2
# 2          20210913                   1                2            3
# 3          20201214                   3                1            4
# 4          20210907                   1                1            5

# %%
# Convert both columns to string
real_est_cleaned['List Year'] = real_est_cleaned['List Year'].astype(str)
date_dimension['date_iso_format'] = date_dimension['date_iso_format'].astype(str)

# Merge the dataframes
merged_df = real_est_cleaned.merge(date_dimension, left_on='List Year', right_on='date_iso_format', how='left')

# %%
# Update the 'List Year' with 'date_id'
real_est_cleaned['List Year'] = merged_df['date_id']

# %%
real_est_cleaned.head()
# Out:
#   List Year Date Recorded  Assessed Value  Sale Amount  Sales Ratio  \
# 0  20200101    2021-04-14          133000     248400.0       0.5354
# 1  20200101    2021-05-26          110500     239900.0       0.4606
# 2  20200101    2021-09-13          150500     325000.0       0.4630
# 3  20200101    2020-12-14          127400     202500.0       0.6291
# 4  20200101    2021-09-07          217640     400000.0       0.5441
#
#   Date Recorded ISO  residentialtype_id  propertytype_id  location_id
# 0          20210414                   1                1            1
# 1          20210526                   2                1            2
# 2          20210913                   1                2            3
# 3          20201214                   3                1            4
# 4          20210907                   1                1            5

# %%
# Convert 'List Year' to datetime and format as 'date_id'
df['listeddate_id'] = pd.to_datetime(df['List Year'], format='%Y').dt.strftime('%Y%m%d')


new_column_names = {
    'Assessed Value': 'assessed_value',
    'Sale Amount': 'sales_amount',
    'Sales Ratio': 'sales_ratio',
    'location_id': 'location_id',
    'Date Recorded ISO': 'recordeddate_id',
    'List Year': 'listeddate_id',
}

real_est_cleaned = real_est_cleaned.rename(columns=new_column_names)

real_est_cleaned['fact_id'] = range(1, len(real_est_cleaned) + 1)

new_order = ['fact_id', 'sales_amount', 'assessed_value', 'sales_ratio', 'location_id','recordeddate_id', 'listeddate_id', 'propertytype_id', 'residentialtype_id']
real_est_cleaned = real_est_cleaned[new_order]

real_est_cleaned.head()
# Out:
#    fact_id  sales_amount  assessed_value  sales_ratio  location_id  \
# 0        1      248400.0          133000       0.5354            1
# 1        2      239900.0          110500       0.4606            2
# 2        3      325000.0          150500       0.4630            3
# 3        4      202500.0          127400       0.6291            4
# 4        5      400000.0          217640       0.5441            5
#
#   recordeddate_id listeddate_id  propertytype_id  residentialtype_id
# 0        20210414      20200101                1                   1
# 1        20210526      20200101                1                   2
# 2        20210913      20200101                2                   1
# 3        20201214      20200101                1                   3
# 4        20210907      20200101                1                   1

# %%
print(real_est_cleaned.columns)
# Out:
# Index(['fact_id', 'sales_amount', 'assessed_value', 'sales_ratio',
#        'location_id', 'recordeddate_id', 'listeddate_id', 'propertytype_id',
#        'residentialtype_id'],
#       dtype='object')

# %%
real_est_cleaned.head(10)
# Out:
#    fact_id  sales_amount  assessed_value  sales_ratio  location_id  \
# 0        1      248400.0          133000     0.535400            1
# 1        2      239900.0          110500     0.460600            2
# 2        3      325000.0          150500     0.463000            3
# 3        4      202500.0          127400     0.629100            4
# 4        5      400000.0          217640     0.544100            5
# 5        6      775000.0          528490     0.681900            6
# 6        7      415000.0          203530     0.490434            7
# 7        8      243000.0          158030     0.650300            8
# 8        9      100000.0           65590     0.655900            9
# 9       10      190790.0          140600     0.736900           10
#
#   recordeddate_id listeddate_id  propertytype_id  residentialtype_id
# 0        20210414      20200101                1                   1
# 1        20210526      20200101                1                   2
# 2        20210913      20200101                2                   1
# 3        20201214      20200101                1                   3
# 4        20210907      20200101                1                   1
# 5        20201215      20200101                1                   1
# 6        20210601      20200101                1                   1
# 7        20210125      20200101                1                   1
# 8        20201113      20200101                1                   4
# 9        20210810      20200101                1                   1

# %%
unique_residentialtype_df.head()
# Out:
#    residentialtype_id residential_type
# 0                   1    Single Family
# 1                   2     Three Family
# 2                   3       Two Family
# 3                   4            Condo
# 4                   5      Four Family

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-272-4e13b80a5a38> in <cell line: 1>()
# ----> 1 real_est_cleaned['recordeddate_id'] = pd.to_datetime(real_est_cleaned['recordeddate_id'], format='%d/%m/%Y')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044                 result = arg.tz_localize("utc")
#    1045     elif isinstance(arg, ABCSeries):
# -> 1046         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047         if not cache_array.empty:
#    1048             result = arg.map(cache_array)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     248         unique_dates = unique(arg)
#     249         if len(unique_dates) < len(arg):
# --> 250             cache_dates = convert_listlike(unique_dates, format)
#     251             # GH#45319
#     252             try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452     if format is not None and format != "mixed":
# --> 453         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     454
#     455     result, tz_parsed = objects_to_datetime64ns(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "2021-04-14" doesn't match format "%d/%m/%Y", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# Update connection string information
host = "cis9440realestbaruch.postgres.database.azure.com"
dbname = "postgres"
user = "rabbybom"
password = "Flowerpot123!"
sslmode = "require"

# Construct connection string
conn_string = "postgresql+psycopg2://{0}:{1}@{2}/{3}?sslmode={4}".format(user, password, host, dbname, sslmode)
engine = create_engine(conn_string)

# Define your schema name
schema_name = "realest"

# Upload the DataFrame to PostgreSQL
unique_residentialtype_df.to_sql('dim_residential_type', engine, if_exists='append', index=False, schema=schema_name)

print("Data has been uploaded successfully")
# Out:
# Data has been uploaded successfully

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# Update connection string information
host = "cis9440realestbaruch.postgres.database.azure.com"
dbname = "postgres"
user = "rabbybom"
password = "Flowerpot123!"
sslmode = "require"

# Construct connection string
conn_string = "postgresql+psycopg2://{0}:{1}@{2}/{3}?sslmode={4}".format(user, password, host, dbname, sslmode)
engine = create_engine(conn_string)

# Define your schema name
schema_name = "realest"

# Upload the DataFrame to PostgreSQL
unique_propertytype_df.to_sql('dim_property_type', engine, if_exists='append', index=False, schema=schema_name)

print("Data has been uploaded successfully")
# Out:
# Data has been uploaded successfully

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# Update connection string information
host = "cis9440realestbaruch.postgres.database.azure.com"
dbname = "postgres"
user = "rabbybom"
password = "Flowerpot123!"
sslmode = "require"

# Construct connection string
conn_string = "postgresql+psycopg2://{0}:{1}@{2}/{3}?sslmode={4}".format(user, password, host, dbname, sslmode)
engine = create_engine(conn_string)

# Define your schema name
schema_name = "realest"

# Upload the DataFrame to PostgreSQL
unique_locations.to_sql('dim_location', engine, if_exists='append', index=False, schema=schema_name)

print("Data has been uploaded successfully")
# Out:
# Data has been uploaded successfully

# %%
real_est_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054108 entries, 0 to 1054107
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   fact_id             1054108 non-null  int64
#  1   sales_amount        1054108 non-null  float64
#  2   assessed_value      1054108 non-null  int64
#  3   sales_ratio         1054108 non-null  float64
#  4   location_id         1054108 non-null  int64
#  5   recordeddate_id     1054108 non-null  object
#  6   listeddate_id       1054108 non-null  object
#  7   propertytype_id     1054108 non-null  int64
#  8   residentialtype_id  1054108 non-null  int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 72.4+ MB

# %%
# Out:
#          fact_id  sales_amount  assessed_value  sales_ratio  location_id  \
# 0              1      248400.0          133000       0.5354            1
# 1              2      239900.0          110500       0.4606            2
# 2              3      325000.0          150500       0.4630            3
# 3              4      202500.0          127400       0.6291            4
# 4              5      400000.0          217640       0.5441            5
# ...          ...           ...             ...          ...          ...
# 1054103  1054104      430000.0          263100       0.6118       661335
# 1054104  1054105      200000.0           79810       0.3990       797582
# 1054105  1054106      360000.0           79590       0.2210       797583
# 1054106  1054107      275000.0          117600       0.4276       161794
# 1054107  1054108      190000.0          130690       0.6878       685149
#
#         recordeddate_id listeddate_id  propertytype_id  residentialtype_id
# 0              20210414      20200101                1                   1
# 1              20210526      20200101                1                   2
# 2              20210913      20200101                2                   1
# 3              20201214      20200101                1                   3
# 4              20210907      20200101                1                   1
# ...                 ...           ...              ...                 ...
# 1054103        20211116      20210101                1                   1
# 1054104        20220920      20210101                1                   4
# 1054105        20220506      20210101                3                   1
# 1054106        20220629      20210101                1                   1
# 1054107        20220426      20210101                2                   1
#
# [1054108 rows x 9 columns]

# %%
real_est_cleaned.head()
# Out:
#      fact_id  sales_amount  assessed_value  sales_ratio  location_id  \
# 0          1      248400.0          133000       0.5354            1
# 2          3      325000.0          150500       0.4630            3
# 24        25      100000.0           47530       0.4753           25
# 92        93      315000.0          154210       0.4895           93
# 110      111      240000.0          120680       0.5028          111
#
#     recordeddate_id listeddate_id  propertytype_id  residentialtype_id
# 0          20210414      20200101                1                   1
# 2          20210913      20200101                2                   1
# 24         20210115      20200101                3                   1
# 92         20210920      20200101                4                   1
# 110        20210528      20200101                5                   1

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# Update connection string information
host = "cis9440realestbaruch.postgres.database.azure.com"
dbname = "postgres"
user = "rabbybom"
password = "Flowerpot123!"
sslmode = "require"

# Construct connection string
conn_string = "postgresql+psycopg2://{0}:{1}@{2}/{3}?sslmode={4}".format(user, password, host, dbname, sslmode)
engine = create_engine(conn_string)

# Define your schema name
schema_name = "realest"

# Upload the DataFrame to PostgreSQL
real_est_cleaned.to_sql('facts_realestate', engine, if_exists='replace', index=False, schema=schema_name)

print("Data has been uploaded successfully")
# Out:
# Data has been uploaded successfully

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# Update connection string information
host = "cis9440realestbaruch.postgres.database.azure.com"
dbname = "postgres"
user = "rabbybom"
password = "Flowerpot123!"
sslmode = "require"

# Construct connection string
conn_string = "postgresql+psycopg2://{0}:{1}@{2}/{3}?sslmode={4}".format(user, password, host, dbname, sslmode)
engine = create_engine(conn_string)

# Define your schema name
schema_name = "realest"

# Upload the DataFrame to PostgreSQL
date_dimension.to_sql('dim_date', engine, if_exists='append', index=False, schema=schema_name)

print("Data has been uploaded successfully")
# Out:
# Data has been uploaded successfully
